# %%
import nibabel as nib 
import numpy as np 
import matplotlib.pyplot as plt 

# load from path 
test_load = nib.load('../ADNI1-Sample/002_S_0413/002_S_0413_2006_11_15/wstrip_mMPRAGE.nii').get_fdata()
test_load.shape 

# looking at a slice 

test = test_load[:,:,59] 
plt.imshow(test) 
plt.show()

# %%
for i in range(5):
    
    plt.subplot(5, 5, i+1 )
    plt.imshow( test_load[:,:, 59+i] )
    plt.gcf().set_size_inches(10,10)
    
plt.show()

# %%
test_load2 = nib.load('../ADNI1-Sample/ADNI1_PET_batch1/ADNI_033_S_0567_PT_ADNI_STATIC_BRAIN__br_raw_20061205164159199_39_S23443_I31777.nii').get_fdata() 

test_load2.shape 
# (128, 128, 47, 1)

test_slice2 = test_load2[:,:,40,0]

plt.imshow(test_slice2)

plt.show()

# %%
flair_test = nib.load('../../Downloads/12_FLAIR_80SL_GP2_TR14000_0_75x0_75x1_5_BW300_7Conc_TE99_400V_120o_ND.nii').get_fdata() 

flair_test.shape

flair_slice = flair_test[:,:,50]

plt.imshow(flair_slice, cmap='gray' )

plt.show()
